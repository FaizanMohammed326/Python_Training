# %%
"""
With Pyplot, you can use the pie() function to draw pie charts:
By default the plotting of the first wedge starts from the x-axis and move counterclockwise:
The size of each wedge is determined by comparing the value with all the other values, by using this formula:
x/sum(x)
"""
from matplotlib import pyplot as plt

x = [20,12,35,25,8]
plt.pie(x)
plt.show()

# %%
"""
Add labels to the pie chart with the labels parameter.
The label parameter must be an array with one label for each wedge:
"""

mylabel = ['Maths','Science','English','Social','PE']
plt.pie(x, labels = mylabel)
plt.show()

# %%
"""
As mentioned the default start angle is at the x-axis, but you can change the start angle by specifying a startangle parameter
in degrees.
"""
plt.pie(x, labels = mylabel, startangle = 75)
plt.show()

# %%
"""
explode parameter lets one or more wedges to stand out
The explode parameter, if specified, and not None, must be an array with one value for each wedge.
"""
explode_values = [0,0,0.1,0,0]
plt.pie(x, labels=mylabel, explode=explode_values)
plt.show()

# %%
"""
Add a shadow to the pie chart by setting the shadows parameter to True:
"""
plt.pie(x, labels=mylabel, explode=explode_values, shadow=True)
plt.show()

# %%
"""
You can set the color of each wedge with the colors parameter.

"""
mycolors = ['red', 'yellow', 'orange', 'cyan', 'green']
plt.pie(x, labels=mylabel, colors=mycolors)
plt.show()

# %%
"""
To add a list of explanation for each wedge, use the legend() function:
also we can pass the title to legends inside legend function.
"""
plt.pie(x, colors=mycolors, labels=mylabel)
plt.legend(title='subjects')
plt.show()
