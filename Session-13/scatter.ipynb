# %%
"""
With Pyplot, you can use the scatter() function to draw a scatter plot.
The scatter() function plots one dot for each observation. It needs two arrays of the same length,
one for the values of the x-axis, and one for values on the y-axis:
"""
from matplotlib import pyplot as plt

x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]
plt.scatter(x,y)
plt.show()

# %%
"""
You can set your own color for each scatter plot with the color or the c argument:
"""
a = [2,2,8,1,15,8,12,9,7,3,11,4,7,14,12]
b = [100,105,84,105,90,99,90,95,94,100,79,112,91,80,85]
plt.scatter(x, y, color = 'red')
plt.scatter(a, b, color = 'green')
plt.show()

# %%
"""
You can even set a specific color for each dot by using an array of colors as value for the c argument:
"""
x = [12,23,14,5,7]
y = [10,5,17,9,4]
colors = ["black","orange","purple","cyan","brown"]
plt.scatter(x,y,c=colors)
plt.show()

# %%
"""
You can change the size of the dots with the s argument.
"""
y = [2,2,8,1,15,8,12,9,7,3,11,4,7]
x = [100,105,84,105,90,99,90,95,94,100,79,112,91]
sizes = [20,50,100,200,500,1000,60,90,10,300,600,800,75]
plt.scatter(x, y, color = 'yellow', s=sizes)
plt.show()

# %%
"""
You can adjust the transparency of the dots with the alpha argument.

"""
plt.scatter(x, y, s=sizes, alpha = 0.5 )
plt.show()
